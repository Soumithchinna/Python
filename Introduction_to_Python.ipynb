# %% [raw]
# 1. For running the program we need software known compiler or interpreter
# 2. For writting the program we need IDE(Integrated development Environment)
# 3. Code ==> IDE ==> Interpret/compiler ==> Byte_code ==> PVM ==>Output ==>IDE

# %% [markdown]
# # Python

# %% [markdown]
# '''Python is a general purpose programming language. (Ex. Solving the problems, automate)
# Python is a high level programming language.
# Developed by Guido Van Rossam in 1989, working at National Institute at Netherland.
# But officially Python was launched in Feb 20 1991.
# This is the firsst programming language for beginners'''

# %% [markdown]
#  Python is a open source language.
# Anyone can modify the code of python.
# c+python=CPython

# %% [markdown]
# # How Guido has written the python

# %% [raw]
# # 1. Functional programming Features from C.
# # 2. Object Oriented Programming features from C++
# # 3. Scripting language feature from perl and shell
# # 4. Modular programming from modula-3
# # 5. Most of the syntax from c and ABC.

# %% [markdown]
# # Features of Python

# %% [markdown]
# 1. Python is simple and Easy.
# 2. Freware and open source.
# 3. High level programming language.
# 4. Platform independent
# 5. Python is portable.
# 6. Python is dynamically typed language.
# 7. Python is procedure oriented(like "C") and object oriented(LIKE C++)
# 8. Interpreted language.
# 9. Python is Extensible language(with python you can use other programming language)
# 10. It is a embedded language.
# 11. It have Extensive library.

# %% [markdown]
# # Flavours of Python

# %% [markdown]
# C+Python = CPython
# c+ Python =Cython
# Java + Python =Jython
# Python+Python =PyPython
# #Anaconda+Python=Anacondapython

# %% [markdown]
# # versions of python

# %%
Python 1.0.v -Jan 1994
Python 2.0 V -Oct 2000
Python 3.0 V - Dec 20008
