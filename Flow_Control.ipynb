# %% [markdown]
# # Flow Control

# %% [raw]
# Flow control describe the order in which the statements will be executed.

# %% [markdown]
# ## Types of control Flow

# %% [raw]
# 1.Iterative Statements=for,while
# 2.Transfer Statements=break,continue,pass
# 3.Conditional Statements=if,elif,else

# %% [markdown]
# # Conditional Statement

# %% [markdown]
# #### if

# %% [raw]
# #Single statement
# if condition : statements
# #multiple statements
# if condition:
#     statement-1
#     statement-2
#     statement-3

# %%
name=input("Enter a name")
if name=="Rajkumar":print("Hi", name)
# Out:
# Enter a name Rajkumar
# Hi Rajkumar

# %%
if name=="Rajkumar":
    print("Hello",name)
    print(name+name)
    print("Hi",name , "How are you?")
# Out:
# Hello Rajkumar
# RajkumarRajkumar
# Hi Rajkumar How are you?

# %% [markdown]
# ## if-else condition

# %% [raw]
# if condition:
#     statement-1
# else:
#     statement-2
# if condition is true then statement-1 will be executed,else statement-2 will be executed

# %%
name=input("Enter the name of guest")
if name=="Vinay":
    print("Hi", name, "Welcome to our Hotel")
else  :
    print("Sorry,Mr we don't have your details")
# Out:
# Enter the name of guest gjt
# Sorry,Mr we don't have your details

# %% [markdown]
# # if-elif-else

# %% [markdown]
# if condition1:
#     statement-1
# elif condition2:
#     statement-2
# elif condition3:
#     statement-3
# else:
#     Default statement

# %%
brand=input("What is your favourite brand?")
if brand=="KF":
    print("This is a legend brand")
elif brand=="Old Monk":   
    print("This is the brand of ice")
elif brand=="Signature":
    print("This is my brand")
else:    
    print("I am a teetotaler")
# Out:
# What is your favourite brand? KF
# This is a legend brand

# %% [raw]
# Q1. Finding out the number that belongs in between on 1 to 100.
# Q2. Finding out biggest/smallest number in 3 input
# Q3. Even/Odd

# %%
#Q1. Finding out the number that belongs in between on 1 to 100.
num=int(input("Enter a num"))
if num >1 and num<100:
    print("It belongs in between 1 to 100")
else:    
     print("It  is not belongs in between 1 to 100")
# Out:
# Enter a num 10
# It belongs in between 1 to 100

# %%
#Q2. Finding out biggest/smallest number in 3 input
a=int(input("Enter num"))
b=int(input("Enter num"))
c=int(input("Enter num"))
if a>b and a>c:
    print("gratest value",a)
elif b>c and b>a: 
    print("gratest value",b)
else:    
    print("gratest value",c)
# Out:
# Enter num 5
# Enter num 6
# Enter num 9
# gratest value 9

# %%
#Q2. Finding out smallest number in 3 input
a=int(input("Enter num"))
b=int(input("Enter num"))
c=int(input("Enter num"))
if a<b and a<c:
    print("smallest value",a)
elif b<c and b<a: 
    print("smallest value",b)
else:    
    print("smallest value",c)
# Out:
# Enter num 10
# Enter num 25
# Enter num 30
# smallest value 10

# %%
#Q3. Even/Odd

num=int(input("Enter a num"))
if num%2==0:
    print("Even")
else:    
    print("Odd")
# Out:
# Enter a num 10
# Even

# %%
#Q4 check whether the person is elgible to do vote
age=int(input("Enter age"))
if age>18:
    print("He is elgible")
else:    
    print("He is not elgible")
# Out:
# Enter age 24
# He is elgible
