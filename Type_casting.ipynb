# %% [markdown]
# # Type Casting

# %% [markdown]
# Converting one data type to others

# %%
#int
#float, complex,str, bool

# %%
a=10
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 10.0

# %%
complex(a)
# Out:
# (10+0j)

# %%
str(a)
# Out:
# '10'

# %%
bool(a)
# Out:
# True

# %%
#float
#int,complex,str, bool

# %%
b=12.50
type(b)
# Out:
# float

# %%
c=int(b)
type(c)
# Out:
# int

# %%
str(b)
# Out:
# '12.5'

# %%
complex(b)
# Out:
# (12.5+0j)

# %%
bool(b)
# Out:
# True

# %%
#str,
it can't be converted into int,
it can't be converted into float,
it can converted to bool

# %%
name='soumith'
type(name)
# Out:
# str

# %%
bool(name)
# Out:
# True

# %% [markdown]
# #complex-
# complex-int it is not possible
# complex-float it is not possibe
# complex-string is possible
# complex-bool is possible

# %%
com=5+10j
type(com)
# Out:
# complex

# %%
str(com)
# Out:
# '(5+10j)'

# %%
bool(com)
# Out:
# True
