# %% [markdown]
# # Introduction to Jupyter

# %%
# Type of Cell 
# 1. Code -- It is used to write the program
# 2. Markdown -- It is used to mark the headings  with formate
# 3. Raw -- Raw text without formate

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Hello Guys

# %% [raw]
# Hello text

# %% [raw]
# Esc+ R = Raw
# Esc + M = Markdown
# Esc + Y = Code

# %% [markdown]
# # How to give Heading

# %%
# Heading
## Heading
### Heading
#### Heading
#####Heading
###### Heading

# %% [markdown]
# # Heading

# %% [markdown]
# ## Heading

# %% [markdown]
# ## Heading

# %% [raw]
# we can change heading size upto 6 sizes (Note : use Esc + M = TO make it as markup then press shift + enter) and we can use Esc + 1 To 6 to change the heading

# %%
'Formating'
# Out:
# 'Formating'

# %% [markdown]
# # How to write  in bold Formate

# %% [raw]
# syntax : **Text**

# %% [markdown]
# **Hello Guys**

# %% [markdown]
# ## **How to write in Italic**

# %% [raw]
# Syntax : *Text*

# %% [markdown]
# *Hello*

# %% [markdown]
# # How to write bold + Italic

# %% [raw]
# syntax : ***Text***

# %% [markdown]
# ***Hello***

# %% [markdown]
# Unordered List

# %% [raw]
# syntax : - Text1
#          - Text2

# %% [markdown]
# - First_Day
# - Second_Day
# - Third_Day

# %% [raw]
# Esc + A = Adding cell Above
# Esc + b = Adding cell Below
# Esc + DD = Delete cell
