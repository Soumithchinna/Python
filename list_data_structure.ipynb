# %% [markdown]
# # List Data Structure

# %% [raw]
# We want to represent a group of data/object as a single entity where insertion order preserve and duplicates are allowed
# -- Where insertion order preserve and
# -- duplicates are allowed
# -- heterogeneous objects are allowed
# -- its growable nature
# -- we can defferentiate duplicates using index

# %%
list1=["soumith",24,"Kphb"]
list2=["Bharath",23,"Amerpet"]
list1.append(list2)
print(list1)
# Out:
# ['soumith', 24, 'Kphb', ['Bharath', 23, 'Amerpet']]

# %%
list1=[10,20,"a",40,"b","c",10]
list1
# Out:
# [10, 20, 'a', 40, 'b', 'c', 10]

# %%
list=[]
type(list)
# Out:
# list

# %%
list1[0]
# Out:
# 'soumith'

# %%
#define list using keyboard
list=eval(input("Enter a list"))
print("list")
type(list)
del list
# Out:
# Enter a list 20,30,50
# list

# %%
#list as a function
l=list(range(0,10,2))
print(l)
# Out:
# [0, 2, 4, 6, 8]

# %%
#we can create a list using string
s="soumith"
l=list(s)
l
# Out:
# ['s', 'o', 'u', 'm', 'i', 't', 'h']

# %%
s="learning machine is easy"
s.split()
# Out:
# ['learning', 'machine', 'is', 'easy']

# %%
#Accessing the elements of list
#by using index
list1=[10,20,"Name",50.5,20]
list1[0]
# Out:
# 10

# %% [raw]
# #by using slice operator
# list2=list1[start:stop:step]

# %%
n=list(range(10))
n[2:7:2]
# Out:
# [2, 4, 6]

# %%
#mutability
m=[10,20,30]
m[1]=500
m
# Out:
# [10, 500, 30]

# %%
m.append(5)
m
# Out:
# [10, 500, 30, 5]

# %%
m.remove(10)
m
# Out:
# [500, 30, 5]

# %%
#some functions of list

# %%
#len
my_list=[1,2,3,4,5,6,8,7,9,31,3133,56]
len(my_list)
# Out:
# 12

# %%
#count() is used to find out the occurance of specific element
m=[1,2,2,2,5,5,6,6,8,8,8,8]
m.count(5)
# Out:
# 2

# %%
#index() it will return the occurance of first index
m.index(6)
# Out:
# 6

# %%
v=["a","i","o","u"]
v.append("e")
v
# Out:
# ['a', 'i', 'o', 'u', 'e']

# %%
#to add the element at specific index
#insert

# %%
v.insert(1,"e")
v
# Out:
# ['a', 'e', 'i', 'o', 'u', 'e']

# %%
# pop() to delete the element using index

# %%
v.pop()
# Out:
# 'e'

# %%
v
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
#extend() function

list1=["soumith",24,"Kphb"]
list2=["Bharath",23,"Amerpet"]
list1.extend(list2)
print(list1)
# Out:
# ['soumith', 24, 'Kphb', 'Bharath', 23, 'Amerpet']

# %%
#reverse() to reverse the order of elements
list1.reverse()
list1
# Out:
# ['Amerpet', 23, 'Bharath', 'Kphb', 24, 'soumith']

# %%
#sort() sorting the elements
n=[0,5,8,9,3,6,1,7,4]
n.sort()
n
# Out:
# [0, 1, 3, 4, 5, 6, 7, 8, 9]

# %%
fruits=["apple","mango","banana"]
fruits.sort()
fruits
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits.sort(reverse=True)
fruits
# Out:
# ['mango', 'banana', 'apple']

# %%
#Mathematical operations in list

# %%
#+ is use for concatenation
a=[10,20,30]
b=[40,50,60]
print(a+b)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
c=a*3
c
# Out:
# [10, 20, 30, 10, 20, 30, 10, 20, 30]

# %%
#comparing list objects
anm1=['dog','cat','rat']
anm2=['dog','cat','rat']

# %%
anm1==anm2
# Out:
# True

# %%
anm1 is anm2 #the location is different that's why it showing false
# Out:
# False

# %%
#delete all elements present in the list
#clear()

# %%
anm1
# Out:
# ['dog', 'cat', 'rat']

# %%
anm1.clear()
anm1
# Out:
# []

# %% [markdown]
# # Nested list - list within the list

# %%
n=[10,20,[30,40]]
n
# Out:
# [10, 20, [30, 40]]

# %%
n[2]
# Out:
# [30, 40]

# %% [markdown]
# ### nested list vs matrix

# %%
n=[[10,20,30],[40,50,60],[70,80,90]]
print(n)
# Out:
# [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
for i in n:
# Out:
#   Cell In[75], line 1
#     for i in n:
#                ^
# _IncompleteInputError: incomplete input
