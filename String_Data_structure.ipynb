# %% [markdown]
# # String Data structure

# %% [raw]
# --Character char(Python2)
# --String str(Python3)

# %%
name="Pavan"

# %%
name="pavan"

# %%
name='''pavan
kumar'''

# %% [markdown]
# 1.how to access character of a string

# %% [markdown]
# 1. By using indexing

# %% [markdown]
#   2.By slicing operator

# %% [markdown]
# ### By using indexing

# %%
name="soumith"

# %% [markdown]
# Index number should be written in [].

# %%
name[0]
# Out:
# 's'

# %% [markdown]
# ## 2. By using slice operator

# %% [raw]
# name_of_variable=[start:stop:step]

# %%
s="Learning python is very very easy!"
s[0:5]
# Out:
# 'Learn'

# %%
s[0:8:2]
# Out:
# 'Lann'

# %%
s[::-1]
# Out:
# '!ysae yrev yrev si nohtyp gninraeL'

# %% [markdown]
# # Mathematical operators in str

# %% [raw]
# + operator for concatination
# * operartor for repeatation

# %%
print(name+name)
# Out:
# soumithsoumith

# %%
print(name*3)
# Out:
# soumithsoumithsoumith

# %% [markdown]
# # fuctions in strings

# %% [raw]
# len()-the numbers of characters present in the string

# %%
s="soumith"
len(s)
# Out:
# 7

# %% [markdown]
# # checking membership
# we can check the characters are present in the string.

# %%
s="durga"

# %%
"d" in s
# Out:
# True

# %%
"s" not in s
# Out:
# True

# %%
s=input("Enter the main string")
substring=input("Enter the substring")
if substring in s:
    print(substring,":is found in",s)
else:    
    print(substring,":is not found in",s)
# Out:
# Enter the main string soumith chinna
# Enter the substring chinna
# chinna :is found in soumith chinna

# %% [markdown]
# # Comparing the string

# %%
str1=input("Enter first string")
str2=input("Enter second string")
if str1==str2:
    print("Both strings are equal")
elif str1>str2:   
    print("first is greater then second")
else:    
    print("second is greater then first")
# Out:
# Enter first string durga
# Enter second string prasad
# second is greater then first

# %% [markdown]
# # Removing spaces from the string

# %% [raw]
# There are three method to remove space
# 1.rstrip()  ===> remove space right hand side
# 2.lstrip()  ===> remove space left hand side
# 3.strip()   ===> remove space from both sides

# %%
city=input("Enter your city name")
scity=city.strip()
if scity=="Hyderabad":
    print("Hello Hyderabadi...Adaab")
elif scity=="Chennai":    
    print("Hello madrasi...Vanakaam")
elif scity=="Bengluru": 
    print("Hello Subhodaya")
else: 
    print("Enter a valid city name")
# Out:
# Enter your city name     Hyderabad
# Hello Hyderabadi...Adaab

# %% [markdown]
# # Finding substring

# %% [raw]
# we can find out based direction
# 1.Forward direction
# find()-Return first occurance of substring
# index()-It will return the sub string
#
# 2. Backward direction
# rfind()
# rindex()

# %%
s="Machine learning is learning machine"
s.find("machine")
# Out:
# 29

# %%
s.find('a',3,15)
# Out:
# 10

# %% [markdown]
# ### 2.By using index

# %%
s.index("a")
# Out:
# 1

# %%
len(s)
# Out:
# 36

# %% [markdown]
# # Count function

# %%
s="abcdabcdabcdefmbmdsfh"

# %%
s.count("abc")
# Out:
# 3

# %% [markdown]
# # Replacing the string with another string

# %%
#variable.replace(oldstring,newstring)

# %%
s="Learning Python is very Hard"
s.replace("Hard","Easy")
# Out:
# 'Learning Python is very Easy'

# %% [markdown]
# # splitting the string

# %%
#variable.split(separator)

# %%
t="Tata consulting"
t.split(" ")
# Out:
# ['Tata', 'consulting']

# %%
s="learning java is little easy"
l=s.split()
for x in l:
    print(x)
# Out:
# learning
# java
# is
# little
# easy

# %%
d="20-02-2026"
d.split("-")
# Out:
# ['20', '02', '2026']

# %% [markdown]
# # Joining the string

# %%
#separator.join(group of strings)
t=("sunny","bunny","funny")
s=",,,".join(t)
s
# Out:
# 'sunny,,,bunny,,,funny'
