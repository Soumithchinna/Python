# %% [raw]
# Operators are symols that perform some operations.
#     There are many types of operators in Python
#
# 1. Arthimetic operator
# 2. Relational operator/ Comparison operator
# 3. Logical operator
# 4. Bitwise operator
# 5. Assignment operator
# 6. special operator

# %% [markdown]
# ###### 1. Arthmetic operator

# %% [raw]
# + Addition
# - subtraction
# * multiplication
# / division
# % modulo
# // floor division
# ** for power//exponentials

# %%
a=10
b=2
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Remainder:",a%b)
print("Only integer value no floor value:",a//b)
print("power:",a**b)
# Out:
# Addition: 12
# Subtraction: 8
# Multiplication: 20
# Division: 5.0
# Remainder: 0
# Only integer value no floor value: 5
# power: 100

# %%
#code for finding out even or odd
a=10
if a%2==0:
    print('Even')
else:    
    print(odd)
# Out:
# Even

# %% [markdown]
# ##### 2.Relational Operator

# %% [raw]
# >,>=,<,<=

# %%
a=50
b=25
print(a>b)
print(a>=b)
print(a<b)
print(a<=b)
# Out:
# True
# True
# False
# False

# %% [markdown]
# #### 3.Equality operator

# %%
# ==, !=

# %%
10==10,10==20
# Out:
# (True, False)

# %%
10!=11
# Out:
# True

# %% [markdown]
# ##### 4. Logical Operator

# %% [raw]
# and,or, not
# and= if both arguments are true then only result is True
# or= if atleast one argument  is True then result is True
# not= not True meaning false, not False is True

# %%
a=10,
b=20
a and b == 10
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
10 and 20
# Out:
# 20

# %% [markdown]
# #### 5. Bitwise Operator

# %% [raw]
# This operator can be used with integer or bool.
# &,|,^,<<,>>

# %% [markdown]
# ##### Conditions

# %% [raw]
# & ==> if both bits are 1 then only 1 otherwise result is 0.

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(5)
# Out:
# '0b101'

# %%
print(4&5)
# Out:
# 4

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(15)
# Out:
# '0b1111'

# %%
print(10&15)
# Out:
# 10

# %% [raw]
# | if atleast one bit is 1 then result is 1 otherwise 0.

# %%
print(10|15)
# Out:
# 15

# %% [raw]
# ^ if bits are different then result is 1, otherwise 0.

# %%
print(10^15)
# Out:
# 5

# %% [markdown]
# ### >> Bitwise Right shift operator

# %%
print(10>>2)
# Out:
# 2

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(2)
# Out:
# '0b10'

# %%
print(10<<2)
# Out:
# 40

# %% [markdown]
# #### << Bitwise left shift operator

# %%
print(10<<2)
# Out:
# 40

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(2)
# Out:
# '0b10'
