# %% [markdown]
# # Tuple

# %% [raw]
# Tuple exactly same as list except that is immutable. Once we create we can't modify.

# %% [raw]
#  1.Inserion order is preserved
# 2.duplicates are allowed
# 3.Heterogeneous object are allowed.
# 4.we use () to store elements and separated by ','.

# %%
t=10,20,30,40

# %%
t
# Out:
# (10, 20, 30, 40)

# %%
type(t)
# Out:
# tuple

# %%
t=(2,3,54,66)

# %%
type(t)
# Out:
# tuple

# %%
t=()

# %%
t
# Out:
# ()

# %%
t=(10,)

# %%
type(t)
# Out:
# tuple

# %%
list1=("sunny","bunny","funny")

# %%
type(list1)
# Out:
# tuple

# %%
t=tuple(list1)

# %%
type(t)
# Out:
# tuple

# %%
t=tuple(range(2,30,3))

# %%
t
# Out:
# (2, 5, 8, 11, 14, 17, 20, 23, 26, 29)

# %% [raw]
# #How to access elements  of tuple
# either by index or slicing

# %% [markdown]
# # By index

# %%
t=10,20,40,60

# %%
t
# Out:
# (10, 20, 40, 60)

# %%
t[0]
# Out:
# 10

# %% [markdown]
# # By using slice operator

# %%
t=10,20,30,40,50,60,70

# %%
t[2:5]
# Out:
# (30, 40, 50)

# %%
t[0:]
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %% [markdown]
# # mathematical operators on tuple

# %%
t1=(10,20,30)
t2=(40,50,60)

# %%
#concatination
t3=t1+t2
t3
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
t4=t1*3
t4
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %% [markdown]
# # few functions in tuple

# %%
#len()
tu=(10,30,4,5,5,8,9,6,7,19,5)

# %%
len(tu)
# Out:
# 9

# %%
#count()
tu.count(5)
# Out:
# 3

# %%
#index
tu.index(4)
# Out:
# 2

# %%
#sorted
tu=10,20,4,8,545,99

# %%
tu_sorted=sorted(tu)

# %%
tu_sorted
# Out:
# [4, 8, 10, 20, 99, 545]

# %%
tup="a","d","s","c","e","b"

# %%
sorted(tup)
# Out:
# ['a', 'b', 'c', 'd', 'e', 's']

# %%
#min() and max()
tu_sorted
# Out:
# [4, 8, 10, 20, 99, 545]

# %%
min(tu_sorted)
# Out:
# 4

# %%
max(tu_sorted)
# Out:
# 545

# %%
#cmp() compare
t1=10,20,30
t2=40,50,60

# %%
t3=10,20,30

# %%
t1==t3
# Out:
# True

# %%
t2==t3
# Out:
# False

# %%
t2>t1
# Out:
# True

# %% [markdown]
# # tuple packing and unpacking

# %%
a=10
b=40
c=60
d=70

# %%
t=a,b,c,d

# %%
t
# Out:
# (10, 40, 60, 70)

# %% [markdown]
# # unpacking

# %%
tu=(2,3,4,5,6,7,8)

# %%
a,b,c,d,e,f,g=tu

# %%
a,b,c,d,e,f,g
# Out:
# (2, 3, 4, 5, 6, 7, 8)

# %% [markdown]
# # Difference b/w list and tuple

# %% [raw]
# 1.Mutable vs immutable
# 2. []/()
# 3.sort and sorted in list and in tuple we can use only sorted
# 4. growable/read only mode
